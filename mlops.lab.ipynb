# %%
from pandas import pandas as pd

# %%
import random

greetings = [
    "Gatekeeper!",
    "whassup!",
    "approve my work!",
]

# Pick a random greeting
selected = random.choice(greetings)
print(selected)
# Out:
# whassup!
